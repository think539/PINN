# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import random
import time
import scipy.optimize

# %%
d=0.35

# %%
#Diffusion Equation(확산계수는 d=1)
def physics_net(net, xt):
    x = xt[:, 0:1]
    t = xt[:, 1:2]
    with tf.GradientTape(persistent=True) as tape_2:
        tape_2.watch(t)
        tape_2.watch(x)
        with tf.GradientTape(persistent=True) as tape_1:
            tape_1.watch(t)
            tape_1.watch(x)
            xt_t = tf.concat([x,t], axis=1)
            u = net(xt_t)
        u_x = tape_1.gradient(u, x)
        u_t = tape_1.gradient(u, t)
        del tape_1
    u_xx = tape_2.gradient(u_x, x)
    del tape_2

    return u_t - d*u_xx
#print(physics_net(NN,tf.convert_to_tensor(xt_col_data, dtype=tf.float32)))

# %%
#MSE = MSE_u + MSE_f
def compute_loss(f, u_bnd_hat, u_bnd_sol):

    loss_col = tf.reduce_mean(tf.square(f))
    loss_bnd = tf.reduce_mean(tf.square(u_bnd_hat[100:200]-u_bnd_hat[200:300]))
    loss_ini = tf.reduce_mean(tf.square(u_bnd_hat[:100]-u_bnd_sol[:100]))
    
    loss = loss_col + loss_bnd + loss_ini

    return loss

# %%
def compute_grad(net, xt_col, xt_bnd, u_bnd_sol):
    with tf.GradientTape() as tape:
        f = physics_net(net,xt_col)
        u_bnd_hat = net(xt_bnd)

        loss = compute_loss(f, u_bnd_hat, u_bnd_sol)

    grads = tape.gradient(loss, net.trainable_variables) #gradients 계산

    return loss, grads

# %%
#어떤 이벤트가 발생했거나 특정 시점에 도달했을 때 시스템에서 호출하는 함수
def callback(arg=None):
    global iter_num
    global instant_loss
    if iter_num % 500 == 0:
        print('iter=', iter_num, ', loss=', instant_loss)
    #train_loss_history.append([iter_num, instant_loss])

    iter_num=iter_num+1

# %%
def diffusion_data():

    # set number of data points
    N_b = 100    # boundary
    N_t = 100    # initial time
    N_c = 10000  # collocation point

    # set boundary
    xmin = -1
    xmax = 1
    tmin = 0.0
    tmax = 1.0

    # initial condition
    initial_xt = np.linspace([xmin, tmin], [xmax, tmin], N_t)
    initial_u = (2-np.sin(np.pi * initial_xt[:,0])).reshape(-1,1)

    # boundary condition
    boundary_up = np.linspace([xmin, tmin], [xmin, tmax], N_b)
    boundary_up_sol = np.array([0]*N_b).reshape(-1, 1)
    boundary_down = np.linspace([xmax, tmin], [xmax, tmax], N_b)
    boundary_down_sol = np.array([0]*N_b).reshape(-1, 1)

    # collection of initial and boundary condition
    xt_bnd = np.concatenate([initial_xt, boundary_up, boundary_down], axis=0)
    u_bnd_sol = np.concatenate([initial_u, boundary_up_sol, boundary_down_sol], axis=0)


    # collocation point
    t_col_data = np.linspace([tmin], [tmax], N_c)
    x_col_data = np.linspace([xmin], [xmax], N_c)
    xt_col_data = np.concatenate([x_col_data, t_col_data], axis=1)
    xt_col = np.concatenate((xt_col_data, xt_bnd), axis=0)

    # convert all to tensors
    xt_col = tf.convert_to_tensor(xt_col, dtype=tf.float32)
    xt_bnd = tf.convert_to_tensor(xt_bnd, dtype=tf.float32)
    u_bnd_sol = tf.convert_to_tensor(u_bnd_sol, dtype=tf.float32)

    return xt_col, xt_bnd, u_bnd_sol

# %% [markdown]
# # L-BFGS-B optimizer

# %%
iter_num=1
instant_loss=0
train_loss_history=[]

# %%
from keras.models import load_model

def save_weights_lbfgs(net):
    net.save_weights('diffusion.h5')

def load_weights_lbfgs(net):
    net.load_weights('diffusion.h5')

# %%
#레이어와 노드의 수는 이곳에서 변경
initializer = tf.keras.initializers.GlorotUniform #모델의 초기의 가중치 값 설정(균등분포)
NN = tf.keras.models.Sequential([
    tf.keras.layers.Input((None,2)),
    tf.keras.layers.Dense(units = 20, activation = 'tanh', kernel_initializer=initializer),
    tf.keras.layers.Dense(units = 20, activation = 'tanh', kernel_initializer=initializer),
    tf.keras.layers.Dense(units = 20, activation = 'tanh', kernel_initializer=initializer),
    tf.keras.layers.Dense(units = 20, activation = 'tanh', kernel_initializer=initializer),
    tf.keras.layers.Dense(units = 20, activation = 'tanh', kernel_initializer=initializer),
    tf.keras.layers.Dense(units = 20, activation = 'tanh', kernel_initializer=initializer),
    tf.keras.layers.Dense(units = 20, activation = 'tanh', kernel_initializer=initializer),
    tf.keras.layers.Dense(units = 20, activation = 'tanh', kernel_initializer=initializer),
    tf.keras.layers.Dense(units = 1, activation='linear')
])

NN.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, None, 20)          60
#
#  dense_10 (Dense)            (None, None, 20)          420
#
#  dense_11 (Dense)            (None, None, 20)          420
#
#  dense_12 (Dense)            (None, None, 20)          420
#
#  dense_13 (Dense)            (None, None, 20)          420
#
#  dense_14 (Dense)            (None, None, 20)          420
#
#  dense_15 (Dense)            (None, None, 20)          420
#
#  dense_16 (Dense)            (None, None, 20)          420
#
#  dense_17 (Dense)            (None, None, 1)           21
#
# =================================================================
# Total params: 3,021
# Trainable params: 3,021
# Non-trainable params: 0
# _________________________________________________________________

# %%
load_weights_lbfgs(NN)

# %%
#L-BFGS기법을 사용하여 gradients를 통해 backpropagation(weight 갱신)을 진행
def train_with_lbfgs(net, xt_col, xt_bnd, u_bnd_sol, lbfgs_num):

    def vec_weight():
        # vectorize weights
        weight_vec = []

        # Loop over all weights(위에서 만든 신경망 NN의 layers의학습 가능한 가중치_weight,biasis)
        for v in net.trainable_variables:
            weight_vec.extend(v.numpy().flatten())

        weight_vec = tf.convert_to_tensor(weight_vec)
        return weight_vec
    w0 = vec_weight().numpy()

    def restore_weight(weight_vec):
        # restore weight vector to model weights
        idx = 0
        for v in net.trainable_variables:
            vs = v.shape

            # weight matrices
            if len(vs) == 2:
                sw = vs[0] * vs[1]
                updated_val = tf.reshape(weight_vec[idx:idx + sw], (vs[0], vs[1]))
                idx += sw

            # bias vectors
            elif len(vs) == 1:
                updated_val = weight_vec[idx:idx + vs[0]]
                idx += vs[0]

            # assign variables (Casting necessary since scipy requires float64 type)
            v.assign(tf.cast(updated_val, dtype=tf.float32))


    def loss_grad(w):
        # update weights in model
        restore_weight(w)
        loss, grads = compute_grad(net, xt_col, xt_bnd, u_bnd_sol)
        # vectorize gradients
        grad_vec = []
        for g in grads:
            grad_vec.extend(g.numpy().flatten())

        # gradient list to array
        # scipy-routines requires 64-bit floats
        loss = loss.numpy().astype(np.float64)
        global instant_loss
        instant_loss = loss
        grad_vec = np.array(grad_vec, dtype=np.float64)

        return loss, grad_vec
    
    return scipy.optimize.minimize(fun=loss_grad, #The objective function to be minimized
                                    x0=w0, #Array of real elements of size (n,) as Initial guess
                                    jac=True, 
                                    method='L-BFGS-B',
                                    callback=callback,
                                    options={'maxiter': lbfgs_num})

# %%
def train(net, lbfgs_num):

    xt_col, xt_bnd, u_bnd_sol = diffusion_data()

    #start time
    t1 = time.time()
    train_with_lbfgs(net, xt_col, xt_bnd, u_bnd_sol, lbfgs_num)
    # Print computation time
    #print('\nComputation time of L-BFGS-B: {} seconds'.format(time.time() - t1))

    save_weights_lbfgs(net)
    
    #global train_loss_history
    #np.savetxt('loss_lbfgs.txt', train_loss_history)
    #train_loss_history = np.array(train_loss_history)

    #plt.plot(train_loss_history[:, 0], train_loss_history[:, 1])
    #plt.yscale("log")
    #plt.show()

# %%
lbfgs_num = 100
for i in range(1, 1001):
    train(NN, lbfgs_num)
    if i%100==0:
        print(i)
# Out:
# iter= 500 , loss= 0.0001101502712117508
# iter= 1000 , loss= 4.139492375543341e-05
# iter= 1500 , loss= 2.115732968377415e-05
# 100
# 200
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [13], in <cell line: 2>()
#       1 lbfgs_num = 100
#       2 for i in range(1, 1001):
# ----> 3     train(NN, lbfgs_num)
#       4     if i%100==0:
#       5         print(i)
#
# Input In [12], in train(net, lbfgs_num)
#       5 #start time
#       6 t1 = time.time()
# ----> 7 train_with_lbfgs(net, xt_col, xt_bnd, u_bnd_sol, lbfgs_num)
#       8 # Print computation time
#       9 #print('\nComputation time of L-BFGS-B: {} seconds'.format(time.time() - t1))
#      11 save_weights_lbfgs(net)
#
# Input In [11], in train_with_lbfgs(net, xt_col, xt_bnd, u_bnd_sol, lbfgs_num)
#      51     grad_vec = np.array(grad_vec, dtype=np.float64)
#      53     return loss, grad_vec
# ---> 55 return scipy.optimize.minimize(fun=loss_grad, #The objective function to be minimized
#      56                                 x0=w0, #Array of real elements of size (n,) as Initial guess
#      57                                 jac=True,
#      58                                 method='L-BFGS-B',
#      59                                 callback=callback,
#      60                                 options={'maxiter': lbfgs_num})
#
# File ~\Anaconda3\lib\site-packages\scipy\optimize\_minimize.py:623, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     620     return _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     621                               **options)
#     622 elif meth == 'l-bfgs-b':
# --> 623     return _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     624                             callback=callback, **options)
#     625 elif meth == 'tnc':
#     626     return _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     627                          **options)
#
# File ~\Anaconda3\lib\site-packages\scipy\optimize\lbfgsb.py:360, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     354 task_str = task.tobytes()
#     355 if task_str.startswith(b'FG'):
#     356     # The minimization routine wants f and g at the current x.
#     357     # Note that interruptions due to maxfun are postponed
#     358     # until the completion of the current minimization iteration.
#     359     # Overwrite f and g:
# --> 360     f, g = func_and_grad(x)
#     361 elif task_str.startswith(b'NEW_X'):
#     362     # new iteration
#     363     n_iterations += 1
#
# File ~\Anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py:267, in ScalarFunction.fun_and_grad(self, x)
#     265 if not np.array_equal(x, self.x):
#     266     self._update_x_impl(x)
# --> 267 self._update_fun()
#     268 self._update_grad()
#     269 return self.f, self.g
#
# File ~\Anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py:233, in ScalarFunction._update_fun(self)
#     231 def _update_fun(self):
#     232     if not self.f_updated:
# --> 233         self._update_fun_impl()
#     234         self.f_updated = True
#
# File ~\Anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py:137, in ScalarFunction.__init__.<locals>.update_fun()
#     136 def update_fun():
# --> 137     self.f = fun_wrapped(self.x)
#
# File ~\Anaconda3\lib\site-packages\scipy\optimize\_differentiable_functions.py:134, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     130 self.nfev += 1
#     131 # Send a copy because the user may overwrite it.
#     132 # Overwriting results in undefined behaviour because
#     133 # fun(self.x) will change self.x, with the two no longer linked.
# --> 134 return fun(np.copy(x), *args)
#
# File ~\Anaconda3\lib\site-packages\scipy\optimize\optimize.py:74, in MemoizeJac.__call__(self, x, *args)
#      72 def __call__(self, x, *args):
#      73     """ returns the the function value """
# ---> 74     self._compute_if_needed(x, *args)
#      75     return self._value
#
# File ~\Anaconda3\lib\site-packages\scipy\optimize\optimize.py:68, in MemoizeJac._compute_if_needed(self, x, *args)
#      66 if not np.all(x == self.x) or self._value is None or self.jac is None:
#      67     self.x = np.asarray(x).copy()
# ---> 68     fg = self.fun(x, *args)
#      69     self.jac = fg[1]
#      70     self._value = fg[0]
#
# Input In [11], in train_with_lbfgs.<locals>.loss_grad(w)
#      37 def loss_grad(w):
#      38     # update weights in model
#      39     restore_weight(w)
# ---> 40     loss, grads = compute_grad(net, xt_col, xt_bnd, u_bnd_sol)
#      41     # vectorize gradients
#      42     grad_vec = []
#
# Input In [5], in compute_grad(net, xt_col, xt_bnd, u_bnd_sol)
#       1 def compute_grad(net, xt_col, xt_bnd, u_bnd_sol):
#       2     with tf.GradientTape() as tape:
# ----> 3         f = physics_net(net,xt_col)
#       4         u_bnd_hat = net(xt_bnd)
#       6         loss = compute_loss(f, u_bnd_hat, u_bnd_sol)
#
# Input In [3], in physics_net(net, xt)
#      12         u = net(xt_t)
#      13     u_x = tape_1.gradient(u, x)
# ---> 14     u_t = tape_1.gradient(u, t)
#      15     del tape_1
#      16 u_xx = tape_2.gradient(u_x, x)
#
# File ~\Anaconda3\lib\site-packages\tensorflow\python\eager\backprop.py:1100, in GradientTape.gradient(self, target, sources, output_gradients, unconnected_gradients)
#    1094   output_gradients = (
#    1095       composite_tensor_gradient.get_flat_tensors_for_gradients(
#    1096           output_gradients))
#    1097   output_gradients = [None if x is None else ops.convert_to_tensor(x)
#    1098                       for x in output_gradients]
# -> 1100 flat_grad = imperative_grad.imperative_grad(
#    1101     self._tape,
#    1102     flat_targets,
#    1103     flat_sources,
#    1104     output_gradients=output_gradients,
#    1105     sources_raw=flat_sources_raw,
#    1106     unconnected_gradients=unconnected_gradients)
#    1108 if not self._persistent:
#    1109   # Keep track of watched variables before setting tape to None
#    1110   self._watched_variables = self._tape.watched_variables()
#
# File ~\Anaconda3\lib\site-packages\tensorflow\python\eager\imperative_grad.py:67, in imperative_grad(tape, target, sources, output_gradients, sources_raw, unconnected_gradients)
#      63 except ValueError:
#      64   raise ValueError(
#      65       "Unknown value for unconnected_gradients: %r" % unconnected_gradients)
# ---> 67 return pywrap_tfe.TFE_Py_TapeGradient(
#      68     tape._tape,  # pylint: disable=protected-access
#      69     target,
#      70     sources,
#      71     output_gradients,
#      72     sources_raw,
#      73     compat.as_str(unconnected_gradients.value))
#
# File ~\Anaconda3\lib\site-packages\tensorflow\python\eager\backprop.py:157, in _gradient_function(op_name, attr_tuple, num_inputs, inputs, outputs, out_grads, skip_input_indices, forward_pass_name_scope)
#     155     gradient_name_scope += forward_pass_name_scope + "/"
#     156   with ops.name_scope(gradient_name_scope):
# --> 157     return grad_fn(mock_op, *out_grads)
#     158 else:
#     159   return grad_fn(mock_op, *out_grads)
#
# File ~\Anaconda3\lib\site-packages\tensorflow\python\ops\math_grad.py:784, in _TanhGrad(op, grad)
#     782 with ops.control_dependencies([grad]):
#     783   y = math_ops.conj(y)
# --> 784   return gen_math_ops.tanh_grad(y, grad)
#
# File ~\Anaconda3\lib\site-packages\tensorflow\python\ops\gen_math_ops.py:11478, in tanh_grad(y, dy, name)
#   11476 if tld.is_eager:
#   11477   try:
# > 11478     _result = pywrap_tfe.TFE_Py_FastPathExecute(
#   11479       _ctx, "TanhGrad", name, y, dy)
#   11480     return _result
#   11481   except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
iter_num
# Out:
# 1584

# %% [markdown]
# # solution

# %%
import math as m
x_data = np.linspace([-1], [1], 100)
t_data = np.linspace([0], [1], 5000)

k = t_data[1]-t_data[0]
h = x_data[1]-x_data[0]

u_data_0 = [2]
for x in x_data[1:99]:
    u_data_0.append(2-m.sin(np.pi * x))
u_data_0.append(2)

u_data=[]
u_data.append(u_data_0)

# %%
d=0.35

# %%
for i in range(len(t_data)-1):
    u_data_t=[float((1-2*d*(k/h**2))*u_data[i][0] + d*(k/h**2)*u_data[i][1] + d*(k/h**2)*u_data[i][-2])]
    for s in range(1,len(x_data)-1):
        sol = float((1-2*d*(k/h**2))*u_data[i][s] + d*(k/h**2)*u_data[i][s+1] + d*(k/h**2)*u_data[i][s-1])
        u_data_t.append(sol)
    u_data_t.append(float((1-2*d*(k/h**2))*u_data[i][99] + d*(k/h**2)*u_data[i][1] + d*(k/h**2)*u_data[i][98]))
    u_data.append(u_data_t)

# %%
d*k/h**2
# Out:
# array([0.17155181])

# %%
u_data = np.array(u_data)

# %%
u_data_l = []
for m in range(len(u_data)):
    u_data_l.append(u_data[m][1:21])

# %%
import scipy.io
scipy.io.savemat('diffusion_data_1.mat', {'x': x_data,'t': t_data,'usol': u_data})

# %%
import scipy.io
data = scipy.io.loadmat('diffusion_data_1.mat')

t = data["t"].flatten() 
x = data["x"].flatten() 
exact = np.real(data["usol"])

from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np


fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

X = np.array([x for i in range(5000)])
Y = np.array([t for i in range(100)]).T
Z = exact


ax.plot_surface(X, Y, Z)
ax.set_zlim(1, 3)

ax.view_init(30,330)
plt.tight_layout()
plt.show()

# %%
import scipy.io
data = scipy.io.loadmat('diffusion_data_1.mat')
t = data["t"].flatten()
x = data["x"].flatten()
exact = np.real(data["usol"]).T

pre_xt = []

for i in range(5000):
    for s in range(100):
        pre_xt.append([x[s], t[i]])

pre_xt = np.array(pre_xt)
pre_u = NN.predict(pre_xt)
pre = pre_u.reshape(5000, 100)
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, None, 2) for input KerasTensor(type_spec=TensorSpec(shape=(None, None, 2), dtype=tf.float32, name='input_2'), name='input_2', description="created by layer 'input_2'"), but it was called on an input with incompatible shape (32, 2).
# 15625/15625 [==============================] - 37s 2ms/step

# %%
import scipy.io
data = scipy.io.loadmat('diffusion_data_1.mat')

t = data["t"].flatten() #2000
x = data["x"].flatten() #20
exact = np.real(data["usol"])

from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np


fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

X = np.array([x for i in range(5000)])
Y = np.array([t for i in range(100)]).T
Z = pre


ax.plot_surface(X, Y, Z)
ax.set_zlim(1, 3)
ax.view_init(30,330)
plt.tight_layout()
plt.show()

# %%
import scipy.io
data = scipy.io.loadmat('diffusion_data_1.mat')

t = data["t"].flatten() #2000
x = data["x"].flatten() #20
exact = np.real(data["usol"])

from mpl_toolkits.mplot3d import axes3d
import matplotlib.pyplot as plt
import numpy as np


fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

X = np.array([x for i in range(5000)])
Y = np.array([t for i in range(100)]).T
Z = pre - exact


ax.plot_surface(X, Y, Z)
ax.set_zlim(-1, 1)
ax.view_init(0,90)
plt.tight_layout()
plt.show()

# %%
np.sqrt(np.linalg.norm(exact-pre, 2))/np.sqrt(np.linalg.norm(exact, 2))
# Out:
# 0.09293654146521274

# %%
plt.plot(x, pre[0], color="red", linestyle = '--')
plt.plot(x, exact[0], color="blue")

plt.plot(x, pre[400], color="red", linestyle = '--')
plt.plot(x, exact[400], color="blue")

plt.plot(x, pre[900], color="red", linestyle = '--')
plt.plot(x, exact[900], color="blue")

plt.plot(x, pre[1500], color="red", linestyle = '--')
plt.plot(x, exact[1500], color="blue")

plt.plot(x, pre[2300], color="red", linestyle = '--')
plt.plot(x, exact[2300], color="blue")

plt.plot(x, pre[-1], color="red", linestyle = '--')
plt.plot(x, exact[-1], color="blue")

# %%
# 그래프 애니메이션

import numpy as np
import matplotlib.pyplot as plt
from matplotlib import animation, rc
fig, ax = plt.subplots()

ax.set_xlim(( 0, 1))
ax.set_ylim((-2, 2))

line1, = ax.plot([], [], lw=3)
line2, = ax.plot([], [], lw=3, linestyle = '--')

def init():
    line1.set_data([], [])
    line2.set_data([], [])
    return (line1, line2,)

def animate(i):
    x = np.linspace(0, 1, 100)
    y = exact[i]
    line1.set_data(x, y)
    line2.set_data(x, pre[i])
    return (line1,)

anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=5000, interval=40, blit=True)

rc('animation', html='html5')
anim.save('diffusion.gif', writer='imagemagick')
anim
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...
